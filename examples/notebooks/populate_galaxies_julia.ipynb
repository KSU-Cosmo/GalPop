# %%
include("../src/file_io.jl")
include("../src/populate_galaxies.jl")
# Out:
# populate_galaxies_julia

# %%
h, s = read_results_fits("../data/test25.fits")
# Out:
# Number of halos: 29129524
# Number of subsamples: 49568375
# (File: ../data/test25.fits
# HDU: 2 (name=HALO)
# Type: Table
# Rows: 29129524
# Columns: Name      Size  Type     TFORM
#          mass            Float64  D
#          x               Float32  E
#          y               Float32  E
#          z               Float32  E
#          sigma           Float32  E
#          velocity        Float32  E      , File: ../data/test25.fits
# HDU: 3 (name=SUBSAMPLE)
# Type: Table
# Rows: 49568375
# Columns: Name           Size  Type     TFORM
#          mass                 Float64  D
#          host_velocity        Float32  E
#          n_particles          UInt32   J
#          x                    Float32  E
#          y                    Float32  E
#          z                    Float32  E
#          velocity             Float32  E      )

# %%
h_mass, h_x, h_y, h_z, h_velocity, h_sigma, s_mass, s_host_velocity, s_n_particles, s_x, s_y, s_z, s_velocity = extract_arrays_from_fits(h, s)
# Out:
# Halo columns: ["mass", "x", "y", "z", "sigma", "velocity"]
# Subsample columns: ["mass", "host_velocity", "n_particles", "x", "y", "z", "velocity"]
# ...

# %%
populate_galaxies_julia(h_mass, h_x, h_y, h_z, h_velocity, h_sigma, s_mass, s_host_velocity, s_n_particles, s_x, s_y, s_z, s_velocity, 13, 0.2, 14, 1, 1, 0, 1, true, -1000.0, 1000.0
)
# Out:
# ([-58.26978302001953, -58.0853271484375, -58.38805389404297, -58.235870361328125, -57.739898681640625, -58.10834884643555, -57.85847854614258, -58.339351654052734, -57.30644989013672, -58.19854736328125  …  822.2520141601562, 823.1019897460938, 822.3579711914062, 822.447998046875, 822.2579956054688, 823.2360229492188, 822.2420043945312, 822.4219970703125, 822.4340209960938, 822.2540283203125], [999.405029296875, -998.2882690429688, -996.642333984375, -995.7506103515625, -993.8348999023438, -992.6074829101562, -992.4192504882812, -991.2254028320312, -989.8843383789062, -988.3035888671875  …  800.6939697265625, 802.4619750976562, 825.8140258789062, 833.4459838867188, 838.8519897460938, 902.9180297851562, 933.3280029296875, 947.0599975585938, 954.0440063476562, 953.8720092773438], [-97.82206726074219, -23.15854263305664, 665.4295654296875, 507.71875, -523.9496459960938, -216.22894287109375, 656.1627807617188, 673.87451171875, -379.000244140625, 204.2238311767578  …  874.2567749023438, 7
# ...

# %%
populate_galaxies_julia(h_mass, h_x, h_y, h_z, h_velocity, h_sigma, s_mass, s_host_velocity, s_n_particles, s_x, s_y, s_z, s_velocity, 12.7, 0.2, 13.5, 1, 1, 0, 1, true, -1000.0, 1000.0
)
# Out:
# ([-58.26978302001953, -58.0853271484375, -58.27721405029297, -58.66228485107422, -58.758853912353516, -57.58872985839844, -58.38805389404297, -57.78950500488281, -58.22340774536133, -58.40107345581055  …  821.926025390625, 822.35400390625, 822.3200073242188, 825.72998046875, 825.9340209960938, 825.8619995117188, 822.4520263671875, 822.3179931640625, 822.9320068359375, 822.3800048828125], [999.405029296875, -998.2882690429688, 999.9654541015625, -997.2163696289062, -996.4177856445312, -996.6921997070312, -996.642333984375, -996.0155639648438, -995.709228515625, -994.1243896484375  …  964.9600219726562, 964.5540161132812, 964.2860107421875, 969.323974609375, 969.3179931640625, 969.4039916992188, 977.5759887695312, 978.3699951171875, 978.7940063476562, 987.219970703125], [-97.82206726074219, -23.15854263305664, 678.1301879882812, 154.69261169433594, -26.33477020263672, 468.89605712890625, 665.4295654296875, 657.73681640625, 658.0746459960938, -462.38671875  …  -80.84440612792969, 137.48
# ...
